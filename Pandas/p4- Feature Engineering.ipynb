# %%
import pandas as pd

file_name = "https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/titanic.csv"
df = pd.read_csv(file_name)

df.head()
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked  survived
# 0      0      0   24160  211.3375       B5        S         1
# 1      1      2  113781  151.5500  C22 C26        S         1
# 2      1      2  113781  151.5500  C22 C26        S         0
# 3      1      2  113781  151.5500  C22 C26        S         0
# 4      1      2  113781  151.5500  C22 C26        S         0

# %%
# Feature eng. is the process of using domain knowledge of the data

def get_family_size(sibsp, parch):
    family_size = sibsp + parch
    return family_size

df["family_size"] = df[["sibsp","parch"]].apply(lambda x: get_family_size(x["sibsp"], x["parch"]), axis=1)
df.head()
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked  survived  family_size
# 0      0      0   24160  211.3375       B5        S         1            0
# 1      1      2  113781  151.5500  C22 C26        S         1            3
# 2      1      2  113781  151.5500  C22 C26        S         0            3
# 3      1      2  113781  151.5500  C22 C26        S         0            3
# 4      1      2  113781  151.5500  C22 C26        S         0            3

# %%
df.tail()
# Out:
#       pclass                       name     sex   age  sibsp  parch  ticket  \
# 1304       3       Zabour, Miss. Hileni  female  14.5      1      0    2665
# 1305       3      Zabour, Miss. Thamine  female   NaN      1      0    2665
# 1306       3  Zakarian, Mr. Mapriededer    male  26.5      0      0    2656
# 1307       3        Zakarian, Mr. Ortin    male  27.0      0      0    2670
# 1308       3         Zimmerman, Mr. Leo    male  29.0      0      0  315082
#
#          fare cabin embarked  survived  family_size
# 1304  14.4542   NaN        C         0            1
# 1305  14.4542   NaN        C         0            1
# 1306   7.2250   NaN        C         0            0
# 1307   7.2250   NaN        C         0            0
# 1308   7.8750   NaN        S         0            0

# %%
df["family_size"] = df["sibsp"] + df["parch"]
df.head()
# Out:
#    pclass                                             name     sex      age  \
# 0       1                    Allen, Miss. Elisabeth Walton  female  29.0000
# 1       1                   Allison, Master. Hudson Trevor    male   0.9167
# 2       1                     Allison, Miss. Helen Loraine  female   2.0000
# 3       1             Allison, Mr. Hudson Joshua Creighton    male  30.0000
# 4       1  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female  25.0000
#
#    sibsp  parch  ticket      fare    cabin embarked  survived  family_size
# 0      0      0   24160  211.3375       B5        S         1            0
# 1      1      2  113781  151.5500  C22 C26        S         1            3
# 2      1      2  113781  151.5500  C22 C26        S         0            3
# 3      1      2  113781  151.5500  C22 C26        S         0            3
# 4      1      2  113781  151.5500  C22 C26        S         0            3

# %%
# how to use and apply lambda

# df['new_col'] = df.apply(lambda x: function(x.col_1, x.col_2), axis=1)

# %%
# # Feature Engineering is the technique of extracting more useful features
